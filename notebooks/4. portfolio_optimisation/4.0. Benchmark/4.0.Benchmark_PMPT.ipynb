# %%
import numpy as np
import pandas as pd
#
from pypfopt import EfficientFrontier, EfficientSemivariance, plotting
#
import importlib
import utilities.variables as variables
import utilities.utility as utility
import utilities.plots as plots
import utilities.mpt_utils as mpt_utils
importlib.reload(variables)
importlib.reload(utility)
importlib.reload(plots)
importlib.reload(mpt_utils)
# Out:
# <module 'utilities.mpt_utils' from '/Users/herbishtini/Documents/UNI/Master Thesis/sustainability_portfolio_optimisation/utilities/mpt_utils.py'>

# %%
# Read in price data
df = pd.read_csv('../../../data/df_monthly_prices_complete.csv', index_col='Date')
df_pct = pd.read_csv('../../../data/df_monthly_returns_complete.csv', index_col='Date')
df_overview = pd.read_csv('../../../data/df_overview.csv', index_col=0)

# %% [markdown]
# ### Train & Test split

# %%
# actual values
df_train = df.head(int(variables.ALL_YEARS_NR - variables.TEST_YEARS_NR) * 12)  
df_test = df.tail(variables.TEST_YEARS_NR * 12)
# Percentage based values
df_pct_train = df_pct.head(int(variables.ALL_YEARS_NR - variables.TEST_YEARS_NR) * 12)
df_pct_test = df_pct.tail(variables.TEST_YEARS_NR * 12)

# %%
df_spread = utility.evenly_spaced_dataframe(df, 200)
df_train_spread = utility.evenly_spaced_dataframe(df_train, 200)

# %% [markdown]
# ### Discrete allocation 5 years

# %%
importlib.reload(mpt_utils)

df_pct_5y = df_pct_train.tail(variables.FIVE_YEARS_NR * 12)
df_pct_5y = df_pct_5y - 1
df_pct_5y
# Out:
#             RS1.L    KE  TEG.DE  LEG.DE   SCS   HNI   AVT  ACCO  VNA.DE  \
# Date
# 2014-11-01  -0.08  0.11   -0.03    0.08  0.00  0.01  0.01  0.06    0.12
# 2014-12-01   0.03 -0.20    0.06    0.04  0.02  0.09 -0.01  0.03    0.09
# 2015-01-01  -0.02 -0.15    0.20    0.10 -0.05 -0.04 -0.03 -0.12    0.10
# 2015-02-01   0.10  0.23    0.04    0.08  0.11  0.04  0.10 -0.04    0.12
# 2015-03-01   0.08  0.13    0.07    0.01  0.01  0.09 -0.03  0.09   -0.09
# 2015-04-01   0.00 -0.10   -0.11   -0.06 -0.07 -0.15 -0.04 -0.05   -0.04
# 2015-05-01  -0.01  0.22    0.02   -0.04 -0.02  0.04  0.03 -0.07   -0.04
# 2015-06-01  -0.11 -0.06   -0.10   -0.07  0.10  0.06 -0.06  0.06    0.08
# 2015-07-01  -0.03 -0.08    0.03    0.10 -0.06 -0.03  0.02  0.05    0.12
# 2015-08-01  -0.08 -0.12   -0.01    0.01 -0.01 -0.06  0.02 -0.07    0.03
# 2015-09-01  -0.02  0.02    0.04    0.10  0.04 -0.08  0.01 -0.07   -0.02
# 2015-10-01   0.15 -0.05    0.11   -0.02  0.05  0.00  0.07  0.14    0.06
# 2015-11-01   0.18  0.01   -0.05    0.03  0.04  0.03  0.00 -0.04   -0.03
# 2015-12-01  -0.01 -0.04    0.03    0.01 -0.26 -0.18 -0.05 -0.08   -0.03
# 2016-01-01  -0.10 -0.09   -0.06   -0.01 -0.14 -0.06 -0.07 -0.15   -0.02
# 2016-02-01   0.13  0.14    0.01    0.02 -0.01 -0.01  0.03  0.20    0.03
# 2016-03-01   0.02 -0.02    0.09    0.09  0.19  0.17  0.08  0.23    0.10
# 2016-04-01   0.07 -0.02   -0.02   -0.02  0.03  0.12 -0.07  0.06   -0.07
# 2016-05-01   0.10  0.03    0.06   -0.01  0.05  0.05  0.00  0.04    0.05
# 2016-06-01  -0.08  0.10   -0.04    0.08 -0.15  0.02 -0.01  0.04    0.10
# 2016-07-01   0.16  0.01    0.13    0.07  0.08  0.12  0.02  0.09    0.08
# 2016-08-01   0.04 -0.04    0.01   -0.03  0.03  0.07  0.01 -0.11   -0.02
# 2016-09-01   0.11  0.14    0.00   -0.03 -0.07 -0.28 -0.01 -0.04   -0.03
# 2016-10-01   0.10  0.00   -0.06   -0.10 -0.03  0.02  0.03  0.15   -0.05
# 2016-11-01   0.20  0.26   -0.03   -0.07  0.16  0.30  0.09  0.12   -0.05
# 2016-12-01   0.07  0.04    0.06    0.03  0.15  0.07  0.04  0.05    0.02
# 2017-01-01   0.03 -0.06   -0.01   -0.02 -0.06 -0.10 -0.02 -0.02   -0.02
# 2017-02-01  -0.02 -0.06    0.03    0.07 -0.05 -0.09 -0.01  0.05    0.09
# 2017-03-01   0.00  0.05   -0.02   -0.01  0.05  0.01 -0.01 -0.02    0.00
# 2017-04-01   0.10  0.02    0.04    0.03  0.03  0.01 -0.15  0.08    0.01
# 2017-05-01   0.13  0.01    0.02    0.06 -0.02 -0.08 -0.05 -0.20    0.05
# 2017-06-01  -0.02  0.04    0.08    0.01 -0.16 -0.07  0.06  0.03    0.03
# 2017-07-01   0.09  0.08    0.01   -0.01 -0.02 -0.05 -0.01  0.00   -0.01
# 2017-08-01   0.02 -0.02    0.01    0.04 -0.03 -0.03  0.00 -0.06    0.04
# 2017-09-01  -0.02  0.14    0.01    0.01  0.17  0.14  0.02  0.09    0.01
# 2017-10-01   0.12  0.02    0.04    0.02 -0.05 -0.17  0.02  0.10    0.05
# 2017-11-01  -0.09 -0.05    0.04    0.02  0.04  0.02  0.04  0.01    0.05
# 2017-12-01   0.00 -0.12    0.03    0.07  0.00  0.11 -0.04 -0.07    0.05
# 2018-01-01  -0.02  0.01    0.00   -0.05  0.03  0.01  0.08 -0.03   -0.04
# 2018-02-01   0.03 -0.06   -0.02   -0.06 -0.12 -0.05  0.00  0.07   -0.05
# 2018-03-01  -0.05 -0.07    0.08    0.07  0.00 -0.02 -0.02  0.00    0.07
# 2018-04-01   0.01 -0.02    0.04    0.05 -0.02 -0.07 -0.06 -0.04    0.03
# 2018-05-01   0.16  0.18    0.03   -0.02  0.09  0.11 -0.03  0.07   -0.03
# 2018-06-01   0.08 -0.02    0.08    0.03 -0.06  0.01  0.13  0.08    0.04
# 2018-07-01  -0.04  0.11    0.03    0.03  0.03  0.16  0.03 -0.08    0.02
# 2018-08-01   0.03 -0.03    0.10    0.09  0.06  0.02  0.10 -0.03    0.07
# 2018-09-01  -0.03 -0.01   -0.03   -0.03  0.27  0.01 -0.08 -0.08   -0.05
# 2018-10-01  -0.14 -0.06   -0.02   -0.05 -0.10 -0.14 -0.10 -0.29   -0.04
# 2018-11-01  -0.17 -0.04    0.05    0.05 -0.02  0.02  0.09  0.01    0.06
# 2018-12-01  -0.01 -0.12   -0.06   -0.10 -0.08 -0.07 -0.18 -0.16   -0.07
# 2019-01-01   0.07  0.04    0.11    0.12  0.12  0.10  0.15  0.30    0.11
# 2019-02-01   0.02 -0.04   -0.07   -0.04  0.06 -0.01  0.06  0.05   -0.03
# 2019-03-01   0.01  0.00    0.07    0.12 -0.17 -0.05  0.00 -0.08    0.08
# 2019-04-01   0.15 -0.02   -0.09   -0.05  0.20  0.01  0.13  0.07   -0.04
# 2019-05-01  -0.06 -0.06    0.05    0.03 -0.07 -0.10 -0.16 -0.20    0.06
# 2019-06-01   0.04  0.14    0.00   -0.04  0.07  0.08  0.11  0.08   -0.08
# 2019-07-01  -0.02 -0.02    0.05    0.06  0.00 -0.03  0.01  0.24    0.05
# 2019-08-01  -0.05 -0.17   -0.01    0.02 -0.08 -0.09 -0.08 -0.05    0.02
# 2019-09-01   0.11  0.10   -0.01   -0.02  0.18  0.15  0.06  0.07    0.03
# 2019-10-01   0.06  0.02    0.04   -0.02 -0.04  0.07 -0.11 -0.07    0.02
#
#             7912.T  ...  DEQ.DE  KIDS  HALO  MATW  9842.T  KVHI  MOON.L   NEO  \
# Date                ...
# 2014-11-01   -0.04  ...    0.00  0.00 -0.09  0.00   -0.01 -0.05    0.00 -0.25
# 2014-12-01    0.05  ...    0.02  0.00  0.10  0.06   -0.04  0.04    0.00 -0.02
# 2015-01-01   -0.02  ...    0.13  0.00  0.48 -0.05   -0.06 -0.04   -0.05 -0.03
# 2015-02-01    0.09  ...    0.11  0.00  0.06  0.05    0.11  0.06    0.00  0.13
# 2015-03-01    0.01  ...    0.01  0.00 -0.05  0.06    0.06  0.18    0.00  0.03
# 2015-04-01    0.08  ...   -0.04  0.00  0.04 -0.06    0.13 -0.11    0.00 -0.03
# 2015-05-01    0.06  ...   -0.01  0.00  0.17  0.03    0.01 -0.08    0.00  0.18
# 2015-06-01   -0.04  ...   -0.10  0.00  0.30  0.07   -0.05  0.08    0.00  0.02
# 2015-07-01    0.09  ...    0.06  0.00  0.03  0.01    0.09 -0.09    0.00  0.13
# 2015-08-01   -0.09  ...   -0.02  0.00 -0.25 -0.05   -0.13 -0.10    0.00  0.00
# 2015-09-01   -0.08  ...    0.01  0.00 -0.23 -0.04   -0.01 -0.10    0.00 -0.06
# 2015-10-01    0.11  ...    0.09  0.00  0.17  0.18    0.03 -0.02    0.00  0.23
# 2015-11-01   -0.04  ...   -0.08  0.00  0.14  0.04    0.06  0.01    0.05  0.13
# 2015-12-01    0.00  ...    0.01  0.00 -0.03 -0.10    0.00 -0.04   -0.05 -0.01
# 2016-01-01   -0.08  ...   -0.03  0.00 -0.49 -0.07   -0.10  0.02    0.02 -0.13
# 2016-02-01   -0.13  ...   -0.01  0.10 -0.08 -0.05   -0.16 -0.05   -0.05 -0.07
# 2016-03-01    0.03  ...    0.06  0.00  0.16  0.09    0.13  0.05    0.00  0.06
# 2016-04-01    0.06  ...   -0.01  0.21  0.11  0.02   -0.04  0.02    0.06  0.21
# 2016-05-01    0.09  ...    0.01 -0.15 -0.05  0.05    0.05 -0.13   -0.05  0.10
# 2016-06-01    0.00  ...    0.00 -0.10 -0.14  0.01   -0.06 -0.09    0.01 -0.10
# 2016-07-01    0.02  ...    0.07 -0.01  0.15  0.08    0.01  0.18    0.04  0.08
# 2016-08-01   -0.09  ...   -0.03  0.01 -0.01  0.03   -0.03 -0.05    0.00 -0.08
# 2016-09-01   -0.06  ...    0.00  0.07  0.23 -0.01    0.03  0.02   -0.02  0.02
# 2016-10-01    0.09  ...   -0.05 -0.07 -0.29 -0.01    0.11 -0.10    0.00 -0.02
# 2016-11-01    0.03  ...   -0.07  0.02  0.37  0.21    0.06  0.37    0.00  0.11
# 2016-12-01    0.07  ...    0.05  0.40 -0.16  0.06    0.02  0.08    0.00 -0.04
# 2017-01-01   -0.01  ...   -0.01  0.00  0.17 -0.12    0.02 -0.12    0.00 -0.06
# 2017-02-01    0.06  ...    0.02 -0.24  0.11 -0.02    0.06 -0.03    0.00  0.00
# 2017-03-01   -0.02  ...   -0.02 -0.07  0.01  0.03   -0.08 -0.16    0.00 -0.02
# 2017-04-01    0.05  ...   -0.03 -0.01  0.08  0.01    0.03 -0.05    0.00 -0.04
# 2017-05-01   -0.01  ...    0.00  0.00 -0.15 -0.07    0.06  0.18    0.00  0.00
# 2017-06-01    0.01  ...   -0.07 -0.02  0.09 -0.04    0.03  0.01    0.00  0.19
# 2017-07-01   -0.02  ...    0.06  0.00 -0.01  0.07    0.00  0.15    0.00  0.05
# 2017-08-01    0.07  ...   -0.06  0.00  0.03 -0.08    0.03  0.08    0.00  0.07
# 2017-09-01    0.04  ...   -0.04  0.00  0.34  0.03    0.09  0.01    0.00  0.10
# 2017-10-01    0.01  ...   -0.01  0.00  0.02  0.01    0.09 -0.03    0.00 -0.22
# 2017-11-01   -0.09  ...    0.03  0.12  0.05 -0.10    0.01 -0.06    0.00  0.07
# 2017-12-01    0.02  ...    0.05 -0.04  0.09 -0.06   -0.02 -0.04    0.00 -0.04
# 2018-01-01   -0.03  ...   -0.07 -0.11 -0.08  0.06    0.03  0.07    0.00 -0.13
# 2018-02-01   -0.07  ...   -0.06  0.04  0.05 -0.08   -0.06 -0.08    0.00  0.09
# 2018-03-01   -0.02  ...    0.00 -0.15  0.00 -0.01    0.01  0.01    0.00 -0.03
# 2018-04-01    0.09  ...    0.00  0.25 -0.03 -0.03   -0.02  0.02    0.04  0.17
# 2018-05-01   -0.01  ...    0.05  0.12 -0.03  0.12   -0.03  0.04    0.00  0.21
# 2018-06-01    0.06  ...   -0.03  0.26 -0.08  0.07    0.00  0.21    0.00  0.13
# 2018-07-01   -0.02  ...    0.05  0.05  0.07 -0.11   -0.06 -0.07    0.00  0.07
# 2018-08-01    0.02  ...   -0.02  0.24  0.02 -0.01   -0.08  0.00    0.00 -0.01
# 2018-09-01    0.06  ...   -0.05  0.05 -0.01 -0.03    0.08  0.05    0.00  0.11
# 2018-10-01   -0.03  ...   -0.02 -0.05 -0.15 -0.17   -0.04 -0.06    0.00  0.20
# 2018-11-01    0.04  ...    0.01 -0.10  0.06  0.01    0.05 -0.09    0.00 -0.11
# 2018-12-01   -0.13  ...   -0.08  0.12 -0.11 -0.03   -0.13 -0.09    0.00 -0.23
# 2019-01-01    0.10  ...    0.07  0.04  0.11  0.10    0.01  0.09    0.00  0.32
# 2019-02-01    0.02  ...   -0.04  0.13  0.07 -0.11    0.05  0.02   -0.03  0.18
# 2019-03-01    0.03  ...    0.04  0.08 -0.07 -0.07    0.05 -0.10    0.00  0.04
# 2019-04-01    0.01  ...   -0.01 -0.08  0.00  0.08   -0.04 -0.04    0.00  0.02
# 2019-05-01   -0.11  ...    0.00 -0.05 -0.09 -0.15   -0.08 -0.05    0.00  0.04
# 2019-06-01   -0.03  ...   -0.09  0.00  0.16  0.03   -0.01  0.17    0.00  0.01
# 2019-07-01    0.00  ...    0.07 -0.09 -0.01 -0.02    0.00 -0.07    0.00  0.11
# 2019-08-01    0.00  ...   -0.04 -0.09 -0.03 -0.14   -0.09 -0.08   -0.01  0.03
# 2019-09-01    0.21  ...    0.10  0.10 -0.06  0.21    0.05  0.15    0.27 -0.23
# 2019-10-01    0.05  ...    0.04  0.10 -0.01  0.04    0.03 -0.04    0.00  0.20
#
#             6055.T   UNP
# Date
# 2014-11-01    0.17  0.00
# 2014-12-01   -0.02  0.02
# 2015-01-01    0.02 -0.02
# 2015-02-01   -0.08  0.03
# 2015-03-01    0.05 -0.10
# 2015-04-01   -0.06 -0.02
# 2015-05-01    0.10 -0.05
# 2015-06-01   -0.02 -0.05
# 2015-07-01    0.02  0.02
# 2015-08-01    0.11 -0.12
# 2015-09-01   -0.03  0.04
# 2015-10-01    0.14  0.01
# 2015-11-01    0.18 -0.06
# 2015-12-01   -0.01 -0.06
# 2016-01-01   -0.09 -0.08
# 2016-02-01    0.13  0.10
# 2016-03-01    0.17  0.02
# 2016-04-01   -0.10  0.10
# 2016-05-01    0.24 -0.03
# 2016-06-01    0.24  0.04
# 2016-07-01   -0.11  0.07
# 2016-08-01    0.05  0.03
# 2016-09-01   -0.01  0.03
# 2016-10-01   -0.02 -0.10
# 2016-11-01    0.00  0.15
# 2016-12-01   -0.03  0.03
# 2017-01-01   -0.06  0.03
# 2017-02-01   -0.05  0.01
# 2017-03-01    0.15 -0.01
# 2017-04-01    0.00  0.06
# 2017-05-01    0.07 -0.01
# 2017-06-01    0.07 -0.01
# 2017-07-01    0.03 -0.05
# 2017-08-01    0.25  0.02
# 2017-09-01    0.10  0.11
# 2017-10-01    0.11  0.00
# 2017-11-01    0.02  0.09
# 2017-12-01    0.23  0.07
# 2018-01-01    0.05  0.00
# 2018-02-01    0.05 -0.02
# 2018-03-01   -0.07  0.04
# 2018-04-01    0.06 -0.01
# 2018-05-01    0.22  0.07
# 2018-06-01   -0.03  0.00
# 2018-07-01   -0.09  0.06
# 2018-08-01    0.03  0.00
# 2018-09-01   -0.05  0.09
# 2018-10-01   -0.13 -0.10
# 2018-11-01   -0.01  0.05
# 2018-12-01   -0.19 -0.10
# 2019-01-01    0.17  0.15
# 2019-02-01    0.12  0.05
# 2019-03-01   -0.04  0.00
# 2019-04-01    0.23  0.06
# 2019-05-01   -0.17 -0.06
# 2019-06-01    0.12  0.02
# 2019-07-01   -0.07  0.06
# 2019-08-01   -0.24 -0.10
# 2019-09-01    0.22  0.01
# 2019-10-01    0.15  0.02
#
# [60 rows x 1653 columns]

# %%
importlib.reload(mpt_utils)
#
weights_5y, mu_5y, S_5y, weights_all_5y = mpt_utils.portfolio_and_plot(df_pct_5y, df)
# Out:
# Expected annual return: 32.8%
# Annual volatility: 20.9%
# Sharpe Ratio: 1.47
# -- Allocation --
# {'TAL': 1, 'CENT': 1, 'SLP': 1, '2685.T': 1, 'TPE.DE': 2, 'SRT3.DE': 1, 'PAR': 1, 'ADUS': 1, 'BURL': 1, 'NSSC': 1, 'FLGT': 4, 'AG1.DE': 2, 'BVB.DE': 3, 'COUR': 1, 'ITI': 2, 'ONTF': 1, 'EBF': 1, 'APLD': 6, 'MPX': 1, 'O5G.DE': 13}
# -- Weights Percentage --
# {'AG1.DE': 0.0322, 'CENT': 0.0886, 'ITI': 0.0208, 'BVB.DE': 0.0277, 'NSSC': 0.0594, 'BURL': 0.0623, 'TPE.DE': 0.0846, 'SRT3.DE': 0.0831, 'PAR': 0.0703, 'ONTF': 0.0208, 'SLP': 0.0856, 'TAL': 0.092, 'FLGT': 0.0361, 'ADUS': 0.0693, '2685.T': 0.0851, 'COUR': 0.0267, 'Other(4)': 0.0554}
# /Users/herbishtini/anaconda3/envs/portfolio_optimisation/lib/python3.11/site-packages/pypfopt/discrete_allocation.py:27: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# <div>                            <div id="dd07730e-3e31-468b-babb-7b93bb37ce04" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd07730e-3e31-468b-babb-7b93bb37ce04")) {                    Plotly.newPlot(                        "dd07730e-3e31-468b-babb-7b93bb37ce04",                        [{"hole":0.3,"insidetextorientation":"radial","labels":["AG1.DE","CENT","ITI","BVB.DE","NSSC","BURL","TPE.DE","SRT3.DE","PAR","ONTF","SLP","TAL","FLGT","ADUS","2685.T","COUR","Other(4)"],"textinfo":"label+percent","textposition":"inside","values":[0.0065,0.0179,0.0042,0.0056,0.012,0.0126,0.0171,0.0168,0.0142,0.0042,0.0173,0.0186,0.0073,0.014,0.0172,0.0054,0.0112],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"marker":{"line":{"color":"#283442"}},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar" ...

# %% [markdown]
# #### Overview

# %%
weights_all_5y
# Out:
# {'TAL': 1,
#  'CENT': 1,
#  'SLP': 1,
#  '2685.T': 1,
#  'TPE.DE': 2,
#  'SRT3.DE': 1,
#  'PAR': 1,
#  'ADUS': 1,
#  'BURL': 1,
#  'NSSC': 1,
#  'FLGT': 4,
#  'AG1.DE': 2,
#  'BVB.DE': 3,
#  'COUR': 1,
#  'ITI': 2,
#  'ONTF': 1,
#  'EBF': 1,
#  'APLD': 6,
#  'MPX': 1,
#  'O5G.DE': 13}

# %%
importlib.reload(mpt_utils)
# Create overview
df_view_5y = mpt_utils.generate_overview_table(weights_all_5y, mu_5y, S_5y, df_pct)
df_view_5y
# Out:
#          Weight  Average Covariance Average Returns Return Last 12 Months  \
# TAL           1           -0.035789          12.01%                48.59%
# CENT          1            0.045263          15.55%                -5.64%
# SLP           1           -0.006316           8.19%                77.26%
# 2685.T        1           -0.047895          12.99%                49.31%
# TPE.DE        2            0.013158          31.08%                -6.28%
# SRT3.DE       1           -0.018947          25.50%                36.06%
# PAR           1           -0.036842          15.97%                41.04%
# ADUS          1           -0.048421          48.01%                30.00%
# BURL          1            0.033684          35.99%                13.37%
# NSSC          1           -0.011053          40.70%               118.24%
# FLGT          4            0.010000          52.65%               167.34%
# AG1.DE        2            0.037895          36.70%               146.96%
# BVB.DE        3           -0.071579          10.23%               -10.30%
# COUR          1            0.085789          44.30%                69.29%
# ITI           2            0.012632          52.98%                26.17%
# ONTF          1            0.088947          12.21%                91.00%
# EBF           1            0.037368          32.70%                 5.85%
# APLD          6            0.017895          19.93%                -6.98%
# MPX           1            0.027368           2.12%               -31.47%
# O5G.DE       13           -0.012105           9.97%                -0.04%
#
#         Return (Actual) Next 12 Months
# TAL                            120.88%
# CENT                            36.67%
# SLP                            118.41%
# 2685.T                         -30.06%
# TPE.DE                           3.02%
# SRT3.DE                        109.75%
# PAR                             70.88%
# ADUS                            19.98%
# BURL                             1.41%
# NSSC                            -8.54%
# FLGT                           289.41%
# AG1.DE                         -44.88%
# BVB.DE                         -43.42%
# COUR                           -49.62%
# ITI                            -29.74%
# ONTF                           -41.85%
# EBF                            -10.73%
# APLD                             3.37%
# MPX                             16.83%
# O5G.DE                          -2.04%

# %% [markdown]
# ### Discrete allocation 20 years

# %%
importlib.reload(mpt_utils)

df_pct_20y = df_pct_train.tail(20 * 12)
df_pct_20y = df_pct_20y - 1
df_pct_20y.head(3)
# Out:
#             RS1.L   KE  TEG.DE  LEG.DE   SCS   HNI   AVT  ACCO  VNA.DE  \
# Date
# 1999-11-01   0.13  0.0     0.0     0.0  0.03  0.10  0.01  0.03     0.0
# 1999-12-01   0.11  0.0     0.0     0.0 -0.08  0.02  0.10  0.00     0.0
# 2000-01-01   0.02  0.0     0.0     0.0 -0.04 -0.12 -0.11 -0.27     0.0
#
#             7912.T  ...  DEQ.DE  KIDS  HALO  MATW  9842.T  KVHI  MOON.L  NEO  \
# Date                ...
# 1999-11-01    0.03  ...     0.0   0.0   0.0 -0.07     0.0 -0.01     0.0  0.0
# 1999-12-01   -0.03  ...     0.0   0.0   0.0  0.18     0.0  0.01     0.0  0.0
# 2000-01-01    0.00  ...     0.0   0.0   0.0 -0.15     0.0  0.22     0.0  0.0
#
#             6055.T   UNP
# Date
# 1999-11-01     0.0 -0.16
# 1999-12-01     0.0 -0.07
# 2000-01-01     0.0 -0.07
#
# [3 rows x 1653 columns]

# %%
weights_20y, mu_20y, S_20y, weights_all_20y = mpt_utils.portfolio_and_plot(df_pct_20y, df, plot_threshold=0.02)
# Out:
# Expected annual return: 32.2%
# Annual volatility: 20.7%
# Sharpe Ratio: 1.46
# -- Allocation --
# {'TAL': 1, 'SLP': 1, 'CENT': 2, '4816.T': 1, 'SRT3.DE': 1, 'ADUS': 1, 'PLUS.L': 1, 'NSSC': 1, 'PAR': 1, 'AOF.DE': 1, 'BVB.DE': 3, 'AG1.DE': 2, 'COUR': 1, 'ONTF': 1, 'APLD': 7, 'EBF': 1, 'MPX': 1, 'EVLV': 1}
# -- Weights Percentage --
# {'EBF': 0.0205, 'AG1.DE': 0.0329, 'CENT': 0.0945, 'BVB.DE': 0.0334, 'NSSC': 0.0678, 'SRT3.DE': 0.0883, 'PAR': 0.0672, 'AOF.DE': 0.0631, 'ONTF': 0.0221, 'SLP': 0.0945, '4816.T': 0.0919, 'TAL': 0.1037, 'ADUS': 0.0775, 'PLUS.L': 0.077, 'APLD': 0.021, 'COUR': 0.0308, 'Other(2)': 0.0139}
# /Users/herbishtini/anaconda3/envs/portfolio_optimisation/lib/python3.11/site-packages/pypfopt/discrete_allocation.py:27: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# <div>                            <div id="3bcdcc0c-492f-4a7b-a2ce-eb3963a29964" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bcdcc0c-492f-4a7b-a2ce-eb3963a29964")) {                    Plotly.newPlot(                        "3bcdcc0c-492f-4a7b-a2ce-eb3963a29964",                        [{"hole":0.3,"insidetextorientation":"radial","labels":["EBF","AG1.DE","CENT","BVB.DE","NSSC","SRT3.DE","PAR","AOF.DE","ONTF","SLP","4816.T","TAL","ADUS","PLUS.L","APLD","COUR","Other(2)"],"textinfo":"label+percent","textposition":"inside","values":[0.004,0.0064,0.0184,0.0065,0.0132,0.0172,0.0131,0.0123,0.0043,0.0184,0.0179,0.0202,0.0151,0.015,0.0041,0.006,0.0027],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"marker":{"line":{"color":"#283442"}},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar ...

# %% [markdown]
# #### Overview

# %%
importlib.reload(mpt_utils)
# Create overview
df_view_20y = mpt_utils.generate_overview_table(weights_all_20y, mu_20y, S_20y, df_pct)
df_view_20y
# Out:
#          Weight  Average Covariance Average Returns Return Last 12 Months  \
# TAL           1           -0.025882          12.01%                48.59%
# SLP           1           -0.016471          15.55%                77.26%
# CENT          2            0.033529          12.99%                -5.64%
# 4816.T        1            0.014118          31.08%                33.20%
# SRT3.DE       1           -0.015882          15.97%                36.06%
# ADUS          1           -0.061765          48.01%                30.00%
# PLUS.L        1            0.025882          52.65%               -32.76%
# NSSC          1           -0.082353          -9.50%               118.24%
# PAR           1            0.031176          36.70%                41.04%
# AOF.DE        1           -0.000588          38.42%                79.41%
# BVB.DE        3           -0.078235          10.23%               -10.30%
# AG1.DE        2            0.077059          44.30%               146.96%
# COUR          1            0.090000          40.25%                69.29%
# ONTF          1            0.115882          52.98%                91.00%
# APLD          7            0.033529          32.70%                -6.98%
# EBF           1            0.005882          21.72%                 5.85%
# MPX           1           -0.012941           2.12%               -31.47%
# EVLV          1           -0.012941           9.97%               -39.11%
#
#         Return (Actual) Next 12 Months
# TAL                            120.88%
# SLP                            118.41%
# CENT                            36.67%
# 4816.T                          39.47%
# SRT3.DE                        109.75%
# ADUS                            19.98%
# PLUS.L                         131.69%
# NSSC                            -8.54%
# PAR                             70.88%
# AOF.DE                         115.37%
# BVB.DE                         -43.42%
# AG1.DE                         -44.88%
# COUR                           -49.62%
# ONTF                           -41.85%
# APLD                             3.37%
# EBF                            -10.73%
# MPX                             16.83%
# EVLV                            81.76%

# %%
importlib.reload(plots)
importlib.reload(mpt_utils)
importlib.reload(variables)

df_view_20y = mpt_utils.generate_overview_table(weights_all_20y, mu_20y, S_20y, df_pct, format_nr=False)
plots.plot_diff(df_view_20y.index.tolist(), df_view_20y['Average Returns'].values, df_view_20y['Return Last 12 Months'].values)
# Out:
# <div>                            <div id="315077f1-5ba5-4907-aae3-e465ec69d676" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("315077f1-5ba5-4907-aae3-e465ec69d676")) {                    Plotly.newPlot(                        "315077f1-5ba5-4907-aae3-e465ec69d676",                        [{"alignmentgroup":"True","hovertemplate":"Return Type=Average Return (%)\u003cbr\u003eTicker=%{x}\u003cbr\u003eReturn (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Average Return (%)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Average Return (%)","offsetgroup":"Average Return (%)","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["TAL","SLP","4816.T","ADUS","NSSC","AOF.DE","AG1.DE","ONTF","EBF","EVLV"],"xaxis":"x","y":[0.1201,0.1555,0.3108,0.4801,-0.095,0.3842,0.443,0.5298,0.2172,0.0997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Return Type=Actual Return (Next Year) (%)\u003cbr\u003eTicker=%{x}\u003cbr\u003eReturn (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Actual Return (Next Year) (%)","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Actual Return (Next Year) (%)","offsetgroup":"Actual Return (Next Year) (%)","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["TAL","SLP","4816.T","ADUS","NSSC","AOF.DE","AG1.DE","ONTF","EBF","EVLV"],"xaxis":"x","y":[0.4859,0.7726,0.332,0.3,1.1824,0.7941,1.4696,0.91,0.0585,-0.3911],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0 ...
