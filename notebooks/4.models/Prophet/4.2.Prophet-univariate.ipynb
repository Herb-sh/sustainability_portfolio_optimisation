# %%
# Python
import pandas as pd
import numpy as np
#
from prophet import Prophet
import matplotlib.pyplot as plt
import plotly.graph_objects as go
#
# Python
from prophet.serialize import model_to_json, model_from_json
#
from pypfopt import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices

#
import logging
logger = logging.getLogger('cmdstanpy')
logger.addHandler(logging.NullHandler())
logger.propagate = False
logger.setLevel(logging.CRITICAL)

# %%
df = pd.read_csv('../../../data/df_monthly_returns_complete_percentage.csv', index_col='Date')

# %% [markdown]
# ### Train & Plot Methods

# %%
def train(dataframe, months=12):
    df_train_long = dataframe.reset_index().melt(id_vars=['Date'], var_name='ticker', value_name='y')
    df_train_long.rename(columns={'Date': 'ds'}, inplace=True)
    
    # model
    models = {}
    forecasts = {}
    
    for ticker, data in df_train_long.groupby('ticker'):
        model = Prophet()
        model.fit(data[['ds', 'y']])  # Train model
    
        future = model.make_future_dataframe(periods=months, freq='ME')  # Forecast next 12 months
        forecast = model.predict(future)
    
        models[ticker] = model
        forecasts[ticker] = forecast
        
    return forecasts

def plot(dataframe, forecasts, months=12):
    # Allocate the last 5 years of data for testing
    min_date = pd.to_datetime(dataframe.index[-1]).replace(day=1) - pd.DateOffset(months=months)
    min_datestr = min_date.strftime('%Y-%m-%d')
    
    # max_date = min_date + pd.DateOffset(months=1)
    # max_datestr = max_date.strftime('%Y-%m-%d')

    df_train = dataframe.loc[dataframe.index < min_datestr]
    # df_test = dataframe.loc[dataframe.index >= min_datestr]

    # Collect 'ds' (date) and 'yhat' from each forecast
    forecast_dfs = [item[['ds', 'yhat']].rename(columns={'yhat': stock}) for stock, item in forecasts.items()]

    # Merge all forecasts on 'ds' (date)
    merged_forecast = forecast_dfs[0]
    for df in forecast_dfs[1:]:
        merged_forecast = merged_forecast.merge(df, on='ds', how='outer')

    # Compute the mean 'yhat' per time point
    y_pred = merged_forecast.iloc[:, 1:].mean(axis=1)
    y_true = dataframe.mean(axis=1)

    #
    train_true_list = y_pred[:len(df_train)]
    test_true_list = y_pred[len(df_train):]

    # Create the plot
    fig = go.Figure()

    # Add the timeseries line
    fig.add_trace(go.Scatter(y=y_true, x=dataframe.index.tolist(), mode='lines', name='Actual returns',
                             line=dict(color='#5c839f', width=2)))  #, line=dict(color='red'))
    # Add the training plot in red
    fig.add_trace(go.Scatter(y=train_true_list, x=dataframe.index.tolist()[:len(train_true_list)],
                             mode='lines', name='Train returns',
                             line=dict(color='red', width=2)))  #, line=dict(color='red')

    # Add the testing plot in green
    fig.add_trace(go.Scatter(y=test_true_list, x=dataframe.index.tolist()[len(train_true_list):],
                             mode='lines', name='Test returns',
                             line=dict(color='green', width=2)))  # , line=dict(color='green')

    fig.add_vline(x=min_datestr, line_color='red', line_dash='dash', line_width=1)

    # Update layout with labels
    fig.update_layout(
        title='1 Year Prediction vs Actual Plot',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Day closing return (%)',
            tickformat='.0%',
            range=[0.75, 1.6]
        ),
        legend=dict(title="Legend"),
        template="plotly_white"
    )
    
    fig.show()

# %% [markdown]
# ### 1 Month Actual vs Prediction

# %%
forecasts_1m = train(dataframe=df, months=1)

# %%
plot(dataframe=df, forecasts=forecasts_1m, months=1)
# Out:
# <div>                            <div id="3fd64177-cda3-433e-9fca-164547094850" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3fd64177-cda3-433e-9fca-164547094850")) {                    Plotly.newPlot(                        "3fd64177-cda3-433e-9fca-164547094850",                        [{"line":{"color":"#5c839f","width":2},"mode":"lines","name":"Actual returns","x":["1999-10-01","1999-11-01","1999-12-01","2000-01-01","2000-02-01","2000-03-01","2000-04-01","2000-05-01","2000-06-01","2000-07-01","2000-08-01","2000-09-01","2000-10-01","2000-11-01","2000-12-01","2001-01-01","2001-02-01","2001-03-01","2001-04-01","2001-05-01","2001-06-01","2001-07-01","2001-08-01","2001-09-01","2001-10-01","2001-11-01","2001-12-01","2002-01-01","2002-02-01","2002-03-01","2002-04-01","2002-05-01","2002-06-01","2002-07-01","2002-08-01","2002-09-01","2002-10-01","2002-11-01","2002-12-01","2003-01-01","2003-02-01","2003-03-01","2003-04-01","2003-05-01","2003-06-01","2003-07-01","2003-08-01","2003-09-01","2003-10-01","2003-11-01","2003-12-01","2004-01-01","2004-02-01","2004-03-01","2004-04-01","2004-05-01","2004-06-01","2004-07-01","2004-08-01","2004-09-01","2004-10-01","2004-11-01","2004-12-01","2005-01-01","2005-02-01","2005-03-01","2005-04-01","2005-05-01","2005-06-01","2005-07-01","2005-08-01","2005-09-01","2005-10-01","2005-11-01","2005-12-01","2006-01-01","2006-02-01","2006-03-01","2006-04-01","2006-05-01","2006-06-01","2006-07-01","2006-08-01","2006-09-01","2006-10-01","2006-11-01","2006-12-01","2007-01-01","2007-02-01","2007-03-01","2007-04-01","2007-05-01","2007-06-01","2007-07-01","2007-08-01","2007-09-01","2007-10-01","2007-11-01","2007-12-01","2008-01-01","2008-02-01","2008-03-01","2008-04-01","2008-05-01","2008-06-01","2008-07-01","2008-08-01","2008-09-01","2008-10-01","2008-11-01","2008-12-01","2009-01-01","2009-02-01","2009-03-01","2009-04-01","2009-05-01","2009-06-01","2009-07-01","2009-08-01","2009-09-01","2009-10-01","2009-11-01","2009-12-01","2010-01-01","2010-02-01","2010-03-01","2010-04-01","2010-05-01","2010-06-01","2010-07-01","2010-08-01","2010-09-01","2010-10-01","2010-11-01","2010-12-01","2011-01-01","2011-02-01","2011-03-01","2011-04-01","2011-05-01","2011-06-01","2011-07-01","2011-08-01","2011-09-01","2011-10-01","2011-11-01","2011-12-01","2012-01-01","2012-02-01","2012-03-01","2012-04-01","2012-05-01","2012-06-01","2012-07-01","2012-08-01","2012-09-01","2012-10-01","2012-11-01","2012-12-01","2013-01-01","2013-02-01","2013-03-01","2013-04-01","2013-05-01","2013-06-01","2013-07-01","2013-08-01","2013-09-01","2013-10-01","2013-11-01","2013-12-01","2014-01-01","2014-02-01","2014-03-01","2014-04-01","2014-05-01","2014-06-01","2014-07-01","2014-08-01","2014-09-01","2014-10-01","2014-11-01","2014-12-01","2015-01-01","2015-02-01","2015-03-01","2015-04-01","2015-05-01","2015-06-01","2015-07-01","2015-08-01","2015-09-01","2015-10-01","2015-11-01","2015-12-01","2016-01-01","2016-02-01","2016-03-01","2016-04-01","2016-05-01","2016-06-01","2016-07-01","2016-08-01","2016-09-01","2016-10-01","2016-11-01","2016-12-01","2017-01-01","2017-02-01","2017-03-01","2017-04-01","2017-05-01","2017-06-01","2017-07-01","2017-08-01","2017-09-01","2017-10-01","2017-11-01","2017-12-01","2018-01-01","2018-02-01","2018-03-01","2018-04-01","2018-05-01","2018-06-01","2018-07-01","2018-08-01","2018-09-01","2018-10-01","2018-11-01","2018-12-01","2019-01-01","2019-02-01","2019-03-01","2019-04-01","2019-05-01","2019-06-01","2019-07-01","2019-08-01","2019-09-01","2019-10-01","2019-11-01","2019-12-01","2020-01-01","2020-02-01","2020-03-01","2020-04-01","2020-05-01","2020-06-01","2020-07-01","2020-08-01","2020-09-01","2020-10-01","2020-11-01","2020-12-01","2021-01-01","2021-02-01","2021-03-01","2021-04-01","2021-05-01","2021-0 ...

# %% [markdown]
# ### 6 Months Actual vs Prediction

# %%
forecasts_6m = train(dataframe=df, months=6)

# %%
plot(dataframe=df, forecasts=forecasts_6m, months=6)
# Out:
# <div>                            <div id="d3022116-8e77-4d3d-84f8-b997b21cf418" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3022116-8e77-4d3d-84f8-b997b21cf418")) {                    Plotly.newPlot(                        "d3022116-8e77-4d3d-84f8-b997b21cf418",                        [{"line":{"color":"#5c839f","width":2},"mode":"lines","name":"Actual returns","x":["1999-10-01","1999-11-01","1999-12-01","2000-01-01","2000-02-01","2000-03-01","2000-04-01","2000-05-01","2000-06-01","2000-07-01","2000-08-01","2000-09-01","2000-10-01","2000-11-01","2000-12-01","2001-01-01","2001-02-01","2001-03-01","2001-04-01","2001-05-01","2001-06-01","2001-07-01","2001-08-01","2001-09-01","2001-10-01","2001-11-01","2001-12-01","2002-01-01","2002-02-01","2002-03-01","2002-04-01","2002-05-01","2002-06-01","2002-07-01","2002-08-01","2002-09-01","2002-10-01","2002-11-01","2002-12-01","2003-01-01","2003-02-01","2003-03-01","2003-04-01","2003-05-01","2003-06-01","2003-07-01","2003-08-01","2003-09-01","2003-10-01","2003-11-01","2003-12-01","2004-01-01","2004-02-01","2004-03-01","2004-04-01","2004-05-01","2004-06-01","2004-07-01","2004-08-01","2004-09-01","2004-10-01","2004-11-01","2004-12-01","2005-01-01","2005-02-01","2005-03-01","2005-04-01","2005-05-01","2005-06-01","2005-07-01","2005-08-01","2005-09-01","2005-10-01","2005-11-01","2005-12-01","2006-01-01","2006-02-01","2006-03-01","2006-04-01","2006-05-01","2006-06-01","2006-07-01","2006-08-01","2006-09-01","2006-10-01","2006-11-01","2006-12-01","2007-01-01","2007-02-01","2007-03-01","2007-04-01","2007-05-01","2007-06-01","2007-07-01","2007-08-01","2007-09-01","2007-10-01","2007-11-01","2007-12-01","2008-01-01","2008-02-01","2008-03-01","2008-04-01","2008-05-01","2008-06-01","2008-07-01","2008-08-01","2008-09-01","2008-10-01","2008-11-01","2008-12-01","2009-01-01","2009-02-01","2009-03-01","2009-04-01","2009-05-01","2009-06-01","2009-07-01","2009-08-01","2009-09-01","2009-10-01","2009-11-01","2009-12-01","2010-01-01","2010-02-01","2010-03-01","2010-04-01","2010-05-01","2010-06-01","2010-07-01","2010-08-01","2010-09-01","2010-10-01","2010-11-01","2010-12-01","2011-01-01","2011-02-01","2011-03-01","2011-04-01","2011-05-01","2011-06-01","2011-07-01","2011-08-01","2011-09-01","2011-10-01","2011-11-01","2011-12-01","2012-01-01","2012-02-01","2012-03-01","2012-04-01","2012-05-01","2012-06-01","2012-07-01","2012-08-01","2012-09-01","2012-10-01","2012-11-01","2012-12-01","2013-01-01","2013-02-01","2013-03-01","2013-04-01","2013-05-01","2013-06-01","2013-07-01","2013-08-01","2013-09-01","2013-10-01","2013-11-01","2013-12-01","2014-01-01","2014-02-01","2014-03-01","2014-04-01","2014-05-01","2014-06-01","2014-07-01","2014-08-01","2014-09-01","2014-10-01","2014-11-01","2014-12-01","2015-01-01","2015-02-01","2015-03-01","2015-04-01","2015-05-01","2015-06-01","2015-07-01","2015-08-01","2015-09-01","2015-10-01","2015-11-01","2015-12-01","2016-01-01","2016-02-01","2016-03-01","2016-04-01","2016-05-01","2016-06-01","2016-07-01","2016-08-01","2016-09-01","2016-10-01","2016-11-01","2016-12-01","2017-01-01","2017-02-01","2017-03-01","2017-04-01","2017-05-01","2017-06-01","2017-07-01","2017-08-01","2017-09-01","2017-10-01","2017-11-01","2017-12-01","2018-01-01","2018-02-01","2018-03-01","2018-04-01","2018-05-01","2018-06-01","2018-07-01","2018-08-01","2018-09-01","2018-10-01","2018-11-01","2018-12-01","2019-01-01","2019-02-01","2019-03-01","2019-04-01","2019-05-01","2019-06-01","2019-07-01","2019-08-01","2019-09-01","2019-10-01","2019-11-01","2019-12-01","2020-01-01","2020-02-01","2020-03-01","2020-04-01","2020-05-01","2020-06-01","2020-07-01","2020-08-01","2020-09-01","2020-10-01","2020-11-01","2020-12-01","2021-01-01","2021-02-01","2021-03-01","2021-04-01","2021-05-01","2021-0 ...

# %% [markdown]
# ### 12 months Actual vs Prediction

# %%
forecasts_12m = train(dataframe=df, months=12)

# %%
plot(dataframe=df, forecasts=forecasts_12m, months=12)
# Out:
# <div>                            <div id="f59cf20e-47b0-4f2f-9136-d2445c4feb38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f59cf20e-47b0-4f2f-9136-d2445c4feb38")) {                    Plotly.newPlot(                        "f59cf20e-47b0-4f2f-9136-d2445c4feb38",                        [{"line":{"color":"#5c839f","width":2},"mode":"lines","name":"Actual returns","x":["1999-10-01","1999-11-01","1999-12-01","2000-01-01","2000-02-01","2000-03-01","2000-04-01","2000-05-01","2000-06-01","2000-07-01","2000-08-01","2000-09-01","2000-10-01","2000-11-01","2000-12-01","2001-01-01","2001-02-01","2001-03-01","2001-04-01","2001-05-01","2001-06-01","2001-07-01","2001-08-01","2001-09-01","2001-10-01","2001-11-01","2001-12-01","2002-01-01","2002-02-01","2002-03-01","2002-04-01","2002-05-01","2002-06-01","2002-07-01","2002-08-01","2002-09-01","2002-10-01","2002-11-01","2002-12-01","2003-01-01","2003-02-01","2003-03-01","2003-04-01","2003-05-01","2003-06-01","2003-07-01","2003-08-01","2003-09-01","2003-10-01","2003-11-01","2003-12-01","2004-01-01","2004-02-01","2004-03-01","2004-04-01","2004-05-01","2004-06-01","2004-07-01","2004-08-01","2004-09-01","2004-10-01","2004-11-01","2004-12-01","2005-01-01","2005-02-01","2005-03-01","2005-04-01","2005-05-01","2005-06-01","2005-07-01","2005-08-01","2005-09-01","2005-10-01","2005-11-01","2005-12-01","2006-01-01","2006-02-01","2006-03-01","2006-04-01","2006-05-01","2006-06-01","2006-07-01","2006-08-01","2006-09-01","2006-10-01","2006-11-01","2006-12-01","2007-01-01","2007-02-01","2007-03-01","2007-04-01","2007-05-01","2007-06-01","2007-07-01","2007-08-01","2007-09-01","2007-10-01","2007-11-01","2007-12-01","2008-01-01","2008-02-01","2008-03-01","2008-04-01","2008-05-01","2008-06-01","2008-07-01","2008-08-01","2008-09-01","2008-10-01","2008-11-01","2008-12-01","2009-01-01","2009-02-01","2009-03-01","2009-04-01","2009-05-01","2009-06-01","2009-07-01","2009-08-01","2009-09-01","2009-10-01","2009-11-01","2009-12-01","2010-01-01","2010-02-01","2010-03-01","2010-04-01","2010-05-01","2010-06-01","2010-07-01","2010-08-01","2010-09-01","2010-10-01","2010-11-01","2010-12-01","2011-01-01","2011-02-01","2011-03-01","2011-04-01","2011-05-01","2011-06-01","2011-07-01","2011-08-01","2011-09-01","2011-10-01","2011-11-01","2011-12-01","2012-01-01","2012-02-01","2012-03-01","2012-04-01","2012-05-01","2012-06-01","2012-07-01","2012-08-01","2012-09-01","2012-10-01","2012-11-01","2012-12-01","2013-01-01","2013-02-01","2013-03-01","2013-04-01","2013-05-01","2013-06-01","2013-07-01","2013-08-01","2013-09-01","2013-10-01","2013-11-01","2013-12-01","2014-01-01","2014-02-01","2014-03-01","2014-04-01","2014-05-01","2014-06-01","2014-07-01","2014-08-01","2014-09-01","2014-10-01","2014-11-01","2014-12-01","2015-01-01","2015-02-01","2015-03-01","2015-04-01","2015-05-01","2015-06-01","2015-07-01","2015-08-01","2015-09-01","2015-10-01","2015-11-01","2015-12-01","2016-01-01","2016-02-01","2016-03-01","2016-04-01","2016-05-01","2016-06-01","2016-07-01","2016-08-01","2016-09-01","2016-10-01","2016-11-01","2016-12-01","2017-01-01","2017-02-01","2017-03-01","2017-04-01","2017-05-01","2017-06-01","2017-07-01","2017-08-01","2017-09-01","2017-10-01","2017-11-01","2017-12-01","2018-01-01","2018-02-01","2018-03-01","2018-04-01","2018-05-01","2018-06-01","2018-07-01","2018-08-01","2018-09-01","2018-10-01","2018-11-01","2018-12-01","2019-01-01","2019-02-01","2019-03-01","2019-04-01","2019-05-01","2019-06-01","2019-07-01","2019-08-01","2019-09-01","2019-10-01","2019-11-01","2019-12-01","2020-01-01","2020-02-01","2020-03-01","2020-04-01","2020-05-01","2020-06-01","2020-07-01","2020-08-01","2020-09-01","2020-10-01","2020-11-01","2020-12-01","2021-01-01","2021-02-01","2021-03-01","2021-04-01","2021-05-01","2021-0 ...

# %% [markdown]
# ## Sharpe Ratio

# %%
def build_efficient_frontier(forecasts):
    # Create DataFrame of forecasted prices
    # Collect 'ds' (date) and 'yhat' from each forecast
    forecast_dfs = [item[['ds', 'yhat']].rename(columns={'yhat': stock}) for stock, item in forecasts.items()]
    
    # Merge all forecasts on 'ds' (date)
    merged_forecast = forecast_dfs[0]
    for df in forecast_dfs[1:]:
        merged_forecast = merged_forecast.merge(df, on='ds', how='outer')
    merged_forecast
    
    merged_forecast = merged_forecast.set_index('ds')

    # Calculate expected returns and sample covariance
    mu_0 = expected_returns.mean_historical_return(merged_forecast)
    
    # Get only tickers with a mean historical return of at least 5% 
    optimal_tickers = mu_0[mu_0 > 0.05].index
    df_optimal = merged_forecast[optimal_tickers]
    
    mu = expected_returns.mean_historical_return(df_optimal)
    S = risk_models.CovarianceShrinkage(df_optimal).ledoit_wolf() # risk_models.sample_cov, # Ledoit-Wolf shrinkage (df_optimal, frequency=12), # Exponential Covariance
    
    
    # Optimize for maximal Sharpe ratio
    ef = EfficientFrontier(mu, S)
    ef_new = EfficientFrontier(mu, S)
    
    raw_weights = ef.max_sharpe()
    cleaned_weights = ef.clean_weights()
    ef.save_weights_to_file("weights.csv")  # saves to file
    #
    ef.portfolio_performance(verbose=True)
    
    return (df_optimal, raw_weights)

# %% [markdown]
# ### 1 Month

# %%
df_forecasts_1m, raw_weights_1m = build_efficient_frontier(forecasts_1m)
# Out:
# Expected annual return: 14.1%
# Annual volatility: 73.2%
# Sharpe Ratio: 0.16

# %% [markdown]
# ### 6 Months

# %%
df_forecasts_6m, raw_weights_6m = build_efficient_frontier(forecasts_6m)
# Out:
# Expected annual return: 13.3%
# Annual volatility: 131.8%
# Sharpe Ratio: 0.09

# %% [markdown]
# ### 12 Months

# %%
df_forecasts_12m, raw_weights_12m = build_efficient_frontier(forecasts_12m)
# Out:
# Expected annual return: 41.4%
# Annual volatility: 1108.4%
# Sharpe Ratio: 0.04

# %% [markdown]
# ## Optimal Allocation

# %% [markdown]
# ### 1 Month

# %%
latest_prices = get_latest_prices(df_forecasts_1m)

da = DiscreteAllocation(raw_weights_1m, latest_prices, total_portfolio_value=10000)
allocation, leftover = da.greedy_portfolio()
print("Discrete allocation:", allocation)
print("Funds remaining: €{:.2f}".format(leftover))
# Out:
# Discrete allocation: {'7564.T': 155, 'RWS.L': 127, 'ILM1.DE': 118, 'BIRD': 117, 'IVT': 121, '6951.T': 77, 'RENT': 76, 'GME': 62, 'AMC': 63, 'NEM.DE': 60, 'TWKS': 60, 'BRKR': 56, 'RCH.L': 55, 'EVC': 50, 'HOV': 53, 'NEO': 49, 'MHO': 46, 'MAN': 46, 'POWW': 50, 'BSL.DE': 49, 'SSP': 40, 'CENT': 47, 'BKNG': 45, 'TPX': 44, 'CACI': 43, '6702.T': 44, 'ALV.DE': 43, 'NBPE.L': 44, 'NYT': 42, 'ONT.L': 42, 'KELYA': 40, 'ITI': 43, 'SMCI': 42, 'CLMB': 40, 'VRTX': 41, 'NTGR': 38, 'IMAX': 37, '7944.T': 43, 'AFL': 39, 'STAA': 39, 'MBG.DE': 38, 'CAR': 38, 'ONL': 39, 'KFY': 36, 'BGFV': 36, '8897.T': 38, '2327.T': 38, 'SAP.DE': 36, '2767.T': 40, 'VSEC': 35, 'STVG.L': 39, 'DXLG': 38, '7936.T': 36, 'HSTM': 34, '8803.T': 36, 'STX': 33, '6588.T': 35, 'WOOF': 36, 'ZUMZ': 35, 'SUP': 35, '9697.T': 35, 'LGEN.L': 33, 'NSP': 32, 'DRH': 31, 'GBF.DE': 31, 'NL': 30, 'AGYS': 31, 'AV.L': 32, '4751.T': 31, 'ASGN': 31, 'MUV2.DE': 31, 'MRL.L': 33, 'MOD': 31, '9107.T': 30, 'SMDS.L': 29, '6736.T': 32, 'FOSL': 31, 'NFG.L': 29, 'FR': 29, 'CTAS': 30, 'PINE.L': 31, 'TEG.DE': 31, 'RELL': 29, 'DHC': 30, 'DLR': 29, 'AGS': 30, 'UTI': 28, 'PFC.L': 30, 'APLD': 29, 'ORA': 29, 'AYI': 27, '7832.T': 29, '2760.T': 29, 'GPI': 26, 'RGL.L': 28, 'BBW': 28, 'AIV': 28, 'RMV.L': 27, 'SHO': 26, 'CMPR': 27, 'FOUR.L': 29, 'TROX': 26, 'SDR.L': 27, 'PATH': 27, '9613.T': 28, '7860.T': 27, 'VID.L': 26, 'LCII': 25, 'KBR': 25, 'BMI': 25, 'PLCE': 23, 'DXC': 25, 'EXLS': 25, '6287.T': 26, 'WRBY': 26, 'LQDT': 25, 'UIS': 23, 'KW': 25, 'MSFT': 24, 'CON.DE': 23, 'BWA': 24, 'CLDT': 24, 'ROL': 24, 'HALO': 23, 'ENTG': 23, '9735.T': 24, '2715.T': 24, 'SPTN': 23, 'DECK': 22, 'EGP': 23, 'CRCT': 25, '4298.T': 23, 'ADV': 23, '7282.T': 23, '1925.T': 23, 'MGRC': 22, 'FTNT': 23, 'TGNA': 22, 'ADP': 22, 'PAG': 22, '9104.T': 22, 'ARCB': 22, 'EBF': 22, 'RDWR': 22, 'HZO': 21, 'OMC': 21, 'TWI': 22, '6758.T': 22, '8114.T': 23, 'DJCO': 22, '8439.T': 22, 'RS': 21, 'NXST': 21, 'SAH': 21, 'LAD': 20, '7508.T': 23, 'AHT.L': 21, 'RCL': 20, 'NOW': 21, 'NEXN.L': 22, 'HTZ': 22, 'SCSC': 20, '9101.T': 21, 'TTWO': 21, 'MTCH': 21, 'ZIG.L': 21, '9719.T': 21, 'NVRI': 20, 'CNC': 19, 'GT': 19, 'RWA.L': 20, 'ABM': 20, 'ITV.L': 19, 'CAL': 19, 'SBGI': 19, 'WTW': 20, 'PRU.L': 19, '8129.T': 20, 'CERS': 19, 'CI': 19, '7912.T': 21, '7741.T': 19, 'TLYS': 20, '9987.T': 20, 'SAFE': 19, 'HLIT': 18, '6703.T': 21, 'ADC': 20, 'KAR': 19, '4307.T': 20, 'CPG.L': 20, '2395.T': 20, 'TRMB': 19, 'IHG.L': 19, 'V': 19, 'LKQ': 19, 'ACTG': 19, 'TTEK': 19, 'PSTG': 20, 'HIG': 18, '6471.T': 19, 'UNM': 18, 'LAUR': 19, 'EPR': 18, '6744.T': 18, 'SITC': 18, 'ADBE': 18, 'JNPR': 17, 'HLX': 18, 'WSM': 17, 'QLYS': 18, '6915.T': 18, '8022.T': 18, 'ZBRA': 17, '4549.T': 17, 'SIG': 17, 'KLAC': 17, 'HLE.DE': 17, 'EVT.DE': 17, 'LZB': 17, 'LVWR': 17, 'SVC': 17, 'CNK': 17, 'RGA': 17, 'MU': 17, 'ICFI': 16, 'FGP.L': 17, 'JEN.DE': 16, 'FNKO': 17, 'WEYS': 16, 'OHI': 16, 'HUBS': 17, 'RARE': 16, 'ELME': 16, 'EVRI': 16, '9433.T': 16, '8591.T': 16, '9684.T': 16, '3738.T': 16, '7606.T': 16, 'SPG': 15, 'GCI': 15, '8968.T': 16, 'ESCA': 15, 'URI': 14, 'DLX': 15, 'GPN': 15, 'KGF.L': 15, 'LDOS': 14, 'FDS': 15, 'REG': 15, 'AMP': 15, '2389.T': 15, 'MET': 14, 'AAD.DE': 14, 'DHL.DE': 14, 'FUTR.L': 14, 'MATX': 14, 'WPC': 14, 'PGNY': 14, 'CFLT': 15, 'LOPE': 14, 'VVI': 14, '7868.T': 14, '6674.T': 14, '6955.T': 14, '7730.T': 14, '4676.T': 14, '7518.T': 14, 'BRX': 13, 'LXS.DE': 13, '6701.T': 14, 'IHS': 13, 'JSG.L': 14, '9409.T': 13, '8960.T': 13, 'PEB': 13, 'ARI': 13, 'CASS': 12, 'AAPL': 12, 'HNI': 12, 'SNWS.L': 13, 'DRVN': 13, 'SLB': 12, 'NTCT': 11, 'CBRE': 12, 'LRCX': 12, '6436.T': 12, 'GTN': 12, 'BC': 12, 'NXT.L': 13, '7762.T': 12, 'MA': 11, 'TPL': 12, 'AIN': 12, 'RHP': 12, 'FDX': 12, 'PRU': 12, 'TBCG.L': 12, 'NWSA': 12, 'PFG': 12, '3107.T': 12, 'LNC': 11, 'HIW': 12, '2331.T': 12, 'FIS': 11, 'NWG.L': 12, '7433.T': 12, '7220.T': 12, 'MODG': 11, 'BAH': 12, 'HNR1.DE': 11, 'EXTR': 11, 'FWONK': 11, 'AOX.DE': 11, 'HQI': 10, 'VZ': 11, 'KIM': 11, 'SCVL': 11, '7701.T': 11, 'PLD': 11, 'ANET': 11, '8958.T': 10, 'W ...
# Funds remaining: €0.80

# %% [markdown]
# ### 6 Months

# %%
latest_prices = get_latest_prices(df_forecasts_6m)

da = DiscreteAllocation(raw_weights_6m, latest_prices, total_portfolio_value=10000)
allocation, leftover = da.greedy_portfolio()
print("Discrete allocation:", allocation)
print("Funds remaining: €{:.2f}".format(leftover))
# Out:
# Discrete allocation: {'CENT': 227, 'GME': 173, 'RGL.L': 146, 'DXLG': 134, 'ILM1.DE': 157, 'AMC': 126, 'AGS': 121, 'NXST': 112, 'PMTS': 107, 'CAR': 100, 'JSG.L': 103, 'RENT': 103, '7944.T': 103, 'IMAX': 85, 'WIX': 82, 'SIG': 82, 'ARLO': 84, 'FNKO': 87, '7936.T': 84, 'WOOF': 84, 'NEM.DE': 83, '7564.T': 84, 'OSW': 77, 'NEO': 78, 'ZUMZ': 81, 'TLYS': 77, 'PFC.L': 78, 'CRCT': 77, 'AGYS': 68, 'BSL.DE': 73, 'HWG.L': 67, 'CLMB': 67, '7419.T': 67, 'PETQ': 67, '7846.T': 69, 'GT': 63, 'EFC': 64, '7832.T': 64, 'SREI.L': 60, 'ENPH': 63, 'FOUR.L': 65, 'GLOB': 57, 'AG1.DE': 59, 'SUP': 60, 'RARE': 58, '7906.T': 57, 'ANET': 56, 'IVAC': 49, '6702.T': 56, 'CNK': 55, 'FLTR.L': 52, 'PINE.L': 55, 'DHC': 53, 'TPL': 53, 'BBW': 51, '6951.T': 49, 'PSTG': 52, 'BKNG': 52, 'FGP.L': 50, '6915.T': 49, 'TWKS': 52, 'GBF.DE': 49, '6425.T': 48, 'AMS.L': 49, 'ISRG': 46, 'ICFI': 47, 'DFIN': 48, 'COUR': 48, '4641.T': 46, '8014.T': 48, 'BKR': 45, 'MRL.L': 48, 'OLED': 41, '2767.T': 49, 'RELL': 44, 'SCVL': 44, 'AIV': 45, 'BIG': 44, 'BIJ.DE': 40, 'NXT.L': 44, 'ASO': 42, '3635.T': 44, 'ACCO': 38, 'DOCS.L': 44, 'IRM': 42, 'VRTX': 44, 'UE': 42, 'FOXT.L': 42, 'FWONK': 42, 'WSM': 38, 'GWI.L': 39, 'CPG.L': 39, '2715.T': 38, 'FDS': 37, '6287.T': 39, '7912.T': 38, '7803.T': 36, '2389.T': 37, 'TPX': 37, 'MDB': 35, 'DLX': 36, 'EVRI': 37, 'ROIC': 35, '9987.T': 36, 'CCS': 35, 'PCH': 34, 'TPIC': 35, '4812.T': 34, 'ENT.L': 34, 'EA': 34, 'RCL': 32, 'FRPH': 33, 'ZD': 31, 'LAUR': 34, 'UPBD': 32, 'NYMT': 32, '3612.T': 33, 'BRX': 33, 'HLX': 33, 'FR': 32, 'CVNA': 33, 'TMHC': 32, 'STAA': 32, 'FAN.L': 31, 'ONTO': 32, '1928.T': 32, 'LRN': 32, '6841.T': 31, 'CMPR': 31, 'PLCE': 29, 'TTK.DE': 31, 'LOVE': 30, 'SVC': 30, '6866.T': 30, 'ONT.L': 31, 'MNG.L': 29, 'TEG.DE': 30, 'POWW': 31, 'FOXF': 29, '9068.T': 29, 'MHO': 28, 'ROL': 28, 'RHP': 27, 'VRA': 28, 'ZIG.L': 28, 'CCEP': 28, 'WM': 27, '8957.T': 27, 'TRTX': 27, 'HABA.DE': 27, '6268.T': 25, 'LTC': 26, '8022.T': 27, 'KFY': 25, '7701.T': 25, '7974.T': 25, '6976.T': 25, 'SFIX': 25, 'NEXN.L': 26, '4568.T': 25, 'RS1.L': 25, 'MBG.DE': 25, 'CARR': 24, 'SDR.L': 24, 'QUAD': 25, 'RBLX': 24, '7762.T': 24, '6981.T': 23, 'GPI': 23, 'KSS': 23, 'SCI': 22, 'CNC': 22, '4298.T': 23, 'DB1.DE': 22, 'RUN': 22, '4839.T': 23, 'HUBS': 22, 'WG.L': 22, 'IFX.DE': 20, '2379.T': 21, 'DXC': 19, '6941.T': 17, 'MCG.L': -7}
# Funds remaining: €0.22

# %% [markdown]
# ### 12 Months

# %%
latest_prices = get_latest_prices(df_forecasts_12m)

da = DiscreteAllocation(raw_weights_12m, latest_prices, total_portfolio_value=10000)
allocation, leftover = da.greedy_portfolio()
print("Discrete allocation:", allocation)
print("Funds remaining: €{:.2f}".format(leftover))
# Out:
# Discrete allocation: {'BGEO.L': 763, 'ILM1.DE': 387, 'BIRD': 250, '8766.T': 42, 'GROW.L': 171, 'CRCT': 144, 'HOV': 137, '3668.T': 134, 'ARLO': 121, 'AG1.DE': 117, '8057.T': 112, 'TWKS': 115, 'IVT': 111, 'FUBO': 104, 'SOHO.L': 94, '2767.T': 99, 'GME': 86, 'FOUR.L': 93, 'ONTF': 88, 'RENT': 94, '8309.T': 86, '8308.T': 86, 'JSG.L': 88, '7936.T': 80, 'BBW': 78, 'COUR': 76, 'PMTS': 78, '7239.T': 75, 'SSP': 68, 'CNK': 75, '8111.T': 73, 'JBL': 69, 'BCPT.L': 66, 'MRVI': 68, 'LQDT': 65, '7740.T': 65, '3104.T': 65, 'CMLS': 61, 'ITI': 65, 'GCI': 64, 'SMCI': 63, 'ONL': 62, '3738.T': 60, 'STEM.L': 56, '4326.T': 54, 'ONT.L': 56, 'LRN': 55, 'TYMN.L': 52, '9766.T': 53, 'BCYC': 52, 'ENPH': 52, 'AHT.L': 51, 'NXT.L': 51, 'TTWO': 50, '7564.T': 53, 'SUP': 54, '7508.T': 52, 'NWG.L': 50, 'SHYF': 50, 'AGS': 50, 'NBPE.L': 49, '6745.T': 48, '9076.T': 48, 'QUAD': 48, 'SDRY.L': 44, '7912.T': 47, 'RWI.L': 45, 'FOSL': 48, 'AGR.L': 46, '8966.T': 45, 'SNWS.L': 44, 'NEXN.L': 43, '8953.T': 42, 'BEZ.L': 42, 'FNKO': 44, 'RESI.L': 41, 'WRBY': 43, 'CMPR': 40, 'RM': 40, 'RCH.L': 42, 'BSL.DE': 43, 'CURY.L': 38, 'CENT': 42, 'TBCG.L': 39, '1911.T': 38, 'DOCS.L': 38, 'WG.L': 38, '3048.T': 37, '8114.T': 37, '8050.T': 37, 'FN': 36, 'VSTO': 36, 'ACTG': 37, 'ASCL.L': 36, '8141.T': 36, 'TM17.L': 37, 'EVRI': 36, 'HTZ': 35, 'AVGO': 34, '8014.T': 34, 'TTEK': 33, '8439.T': 34, '2170.T': 33, '9987.T': 33, '3593.T': 33, '7944.T': 36, '1928.T': 32, '9069.T': 33, '8219.T': 32, 'COMM': 32, '7309.T': 31, '7459.T': 31, '6814.T': 30, '3116.T': 31, 'WOOF': 32, '4301.T': 30, 'DELL': 29, 'HL.L': 28, '9613.T': 30, '5110.T': 30, '8951.T': 29, 'G': 29, 'TPX': 30, 'RUN': 28, '8802.T': 29, '8022.T': 28, '7911.T': 28, '5101.T': 27, 'DFIN': 27, '1925.T': 27, '7282.T': 27, '8159.T': 26, '9332.T': 27, 'THRL.L': 26, 'SREI.L': 26, '7846.T': 26, 'ABDN.L': 26, 'IMAX': 25, 'PINE.L': 27}
# Funds remaining: €0.10
